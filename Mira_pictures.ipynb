# %% [markdown]
# ## This is our tutorial on digital pictures

# %%
import matplotlib.pyplot as plt
import os
import time
from IPython.display import clear_output
import skimage.color as sc
from pylab import *

# %%
path = '/Users/junorman/Google Drive/PhD/Research/Projects/faces/synth_faces_unproc/'

# %%
faces = os.listdir(path)

# %%
#list the number of files in the faces list
len(faces)
# Out:
# 1003

# %%
test_img = plt.imread(path+faces[5])

# %%
test_img_2 = test_img.copy()

# %%
gray_im = sc.rgb2gray(test_img)
imshow(gray_im, cmap='BuPu')

# %%
imshow(gray_im)

# %%
for face in range(len(faces)):
    test_img = plt.imread(path+faces[face])
    plt.imshow(test_img)
    time.sleep(.5)
    plt.show()
    clear_output(wait=True)
# Out:
# -----------------------------------------------------------------------
# KeyboardInterrupt                     Traceback (most recent call last)
# <ipython-input-13-f77b8e30cfd9> in <module>
#       2     test_img = plt.imread(path+faces[face])
#       3     plt.imshow(test_img)
# ----> 4     time.sleep(.5)
#       5     plt.show()
#       6     clear_output(wait=True)
#
# KeyboardInterrupt:

# %%
# Out:
#   File "<ipython-input-16-7318423b9f29>", line 1
#     matplotlib.pyplot.
#                       ^
# SyntaxError: invalid syntax
